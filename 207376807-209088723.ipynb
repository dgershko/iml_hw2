# %% [markdown]
# # IML MAJOR HW2 - Model Selection
# | Name | ID |
# |------|----|
# | Daniel Gershkovich   | 209088723  |
# | Assaf Alon   | 207376807  |

# %%
from matplotlib import pylab 
params = {'xtick.labelsize': 18, 
'ytick.labelsize': 18, 
'axes.titlesize' : 22, 
'axes.labelsize' : 20, 
'legend.fontsize': 18, 
'legend.title_fontsize': 22, 
'figure.titlesize': 24 } 
pylab.rcParams.update(params)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from pprint import pprint
from visualize_clf import visualize_clf

# %%
from prepare import prepare_data
dataframe = pd.read_csv('virus_data.csv')
dataframe = prepare_data(dataframe, dataframe)
# Out:
# ['age', 'weight', 'num_of_siblings', 'happiness_score', 'household_income', 'conversations_per_day', 'sugar_levels', 'sport_activity', 'pcr_date', 'PCR_01', 'PCR_02', 'PCR_03', 'PCR_04', 'PCR_05', 'PCR_06', 'PCR_07', 'PCR_08', 'PCR_09', 'PCR_10', 'spread', 'risk', 'sore_throat', 'shortness_of_breath', 'fever', 'cough', 'smell_loss', 'current_location_x', 'current_location_y', 'is_special_blood', 'is_male']
# <> label age is not normally distribured, p-value = 2.551767044419082e-16, stat = 0.9667889424753151
# <> label weight is not normally distribured, p-value = 5.870226569172681e-07, stat = 0.9909515823677736
# <> label num_of_siblings is not normally distribured, p-value = 8.359734008353972e-27, stat = 0.9080380873228466
# <> label happiness_score is not normally distribured, p-value = 1.0160063609284471e-25, stat = 0.9162916366248498
# <> label household_income is not normally distribured, p-value = 5.277074336028543e-28, stat = 0.8981940930034633
# <> label conversations_per_day is not normally distribured, p-value = 1.1329353499353799e-29, stat = 0.8831715445552624
# <++> label sugar_levels is normally distribured!, p-value = 0.3861198646462678, stat = 0.9985472943855612
# <> label sport_activity is not normally distribured, p-value = 4.7556522594186275e-33, stat = 0.8474694360511615
# <> label pcr_date is not normally distribured, p-value = 2.875894852021224e-20, stat = 0.9496471135613076
# <> label PCR_01 is not normally distribured, p-value = 1.81881391245212e-18, stat = 0.9581020964818443
# <> label PCR_02 is not normally distribured, p-value = 4.6039544947992786e-17, stat = 0.963941071440688
# <> label PCR_03 is not normally distribured, p-value = 3.2005071917558335e-19, stat = 0.9546966942959116
# <++> label PCR_04 is normally distribured!, p-value = 0.449981479405738, stat = 0.9986394374329197
# <> label PCR_05 is not normally distribured, p-value = 1.2531054327562224e-22, stat = 0.9367464047402247
# <> label PCR_06 is not normally distribured, p-value = 1.7054469574995364e-17, stat = 0.9622127666987522
# <++> label PCR_07 is normally distribured!, p-value = 0.8500033995956335, stat = 0.999145472504218
# <> label PCR_08 is not normally distribured, p-value = 4.689392528769016e-25, stat = 0.9210580100526626
# <++> label PCR_09 is normally distribured!, p-value = 0.6885273533260245, stat = 0.9989372986987022
# <++> label PCR_10 is normally distribured!, p-value = 0.2902024380731467, stat = 0.9983858290736449
# <> label sore_throat is not normally distribured, p-value = 3.601331775905234e-46, stat = 0.6172841457078151
# <> label shortness_of_breath is not normally distribured, p-value = 3.9011077481747936e-50, stat = 0.5084277683981591
# <> label fever is not normally distribured, p-value = 1.2580752463603377e-53, stat = 0.39231191850281455
# <> label cough is not normally distribured, p-value = 1.2662636574470928e-51, stat = 0.46142548726014265
# <> label smell_loss is not normally distribured, p-value = 1.0033031538994597e-54, stat = 0.35135737216778484
# <> label current_location_x is not normally distribured, p-value = 2.7155716418825053e-27, stat = 0.9041245483283815
# <> label current_location_y is not normally distribured, p-value = 2.154540515999169e-17, stat = 0.9626247476043399
# <> label is_special_blood is not normally distribured, p-value = 2.1236367013214722e-45, stat = 0.6359215955797952
# <> label is_male is not normally distribured, p-value = 2.0173748833425662e-45, stat = 0.6353931486957295

# %% [markdown]
# ## Task 1 / Q1

# %%
train_data_frame = pd.read_csv('prepared_train_data.csv')
train_data_frame = train_data_frame[['PCR_01', 'PCR_03', 'spread']]
knn = KNeighborsClassifier(n_neighbors=1)
data_frame_data = train_data_frame[['PCR_01', 'PCR_03']]
data_frame_labels = train_data_frame['spread']
knn.fit(data_frame_data.values, data_frame_labels)
visualize_clf(knn, data_frame_data.values, data_frame_labels.values, '1-NN on PCR_01, PCR_03', xlabel='PCR_01', ylabel='PCR_03')

# %% [markdown]
# ### Q2

# %%
from sklearn.model_selection import cross_validate

k_range = list(range(1, 20, 2)) + list(range(20, 871, 85))
test_cv_scores = []
train_cv_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_validate(knn, data_frame_data.values, data_frame_labels, cv=8, n_jobs=8, return_train_score=True)
    test_cv_scores.append(np.mean(scores['test_score']))
    train_cv_scores.append(np.mean(scores['train_score']))

# pprint(cv_scores)

plt.figure(figsize=(10, 6))
plt.semilogx(k_range, train_cv_scores, marker=".", markersize=10, label='Mean Train Accuracy')
plt.semilogx(k_range, test_cv_scores, marker=".", markersize=10, label='Mean Validation Accuracy')
plt.xlabel('k')
plt.ylabel('CV Score')
plt.title('k vs. Cross-Validation Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
best_k_index = np.argmax(test_cv_scores)
best_k = k_range[best_k_index]
print(f'Best k: {best_k}')
print(f'Train score for  k={best_k}: {train_cv_scores[best_k_index]}')
print(f'Test score for  k={best_k}: {test_cv_scores[best_k_index]}')
# Out:
# Best k: 7
# Train score for  k=7: 0.8728571428571429
# Test score for  k=7: 0.854

# %% [markdown]
# ### Q3

# %%
test_data_frame = pd.read_csv('prepared_train_data.csv')
test_data_data = test_data_frame[['PCR_01', 'PCR_03']].values
test_data_labels = test_data_frame['spread']


knn = KNeighborsClassifier(n_neighbors=7)
data_frame_data = train_data_frame[['PCR_01', 'PCR_03']]
data_frame_labels = train_data_frame['spread']
knn.fit(data_frame_data.values, data_frame_labels)
visualize_clf(knn, data_frame_data.values, data_frame_labels.values, '7-NN on PCR_01, PCR_03', xlabel='PCR_01', ylabel='PCR_03')
test_score = knn.score(test_data_data, test_data_labels)
print(test_score)
# Out:
# 0.872

# %% [markdown]
# ## Part 2: Decision Trees

# %%
from sklearn.tree import plot_tree

id3 = DecisionTreeClassifier(criterion='entropy', max_depth=3)
train_data_frame = pd.read_csv('prepared_train_data.csv')
test_data_frame = pd.read_csv('prepared_test_data.csv')
test_data_data = test_data_frame.drop(['spread', 'risk'], axis=1)
test_data_labels = test_data_frame['risk']
train_data_data = train_data_frame.drop(['spread', 'risk'], axis=1)
train_data_labels = train_data_frame['risk']
id3.fit(train_data_data.values, train_data_labels)
train_score = id3.score(train_data_data.values, train_data_labels)
test_score = id3.score(test_data_data.values, test_data_labels)

plt.figure(figsize=(25, 10))
plot_tree(id3, filled=True, feature_names=train_data_data.columns, class_names=['-1', '1'], fontsize=15, rounded=True)

print(f"train score: {train_score}")
print(f"test score: {test_score}")
data_frame_data = train_data_frame[['PCR_01', 'PCR_03']]
data_frame_labels = train_data_frame['spread']
#
# Out:
# train score: 0.715
# test score: 0.616

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ### Q6

# %%
from sklearn.model_selection import GridSearchCV


param_grid = {
    'min_samples_leaf': list(range(1, 41, 2)),
    'max_depth': list(range(1, 15))
}

grid = GridSearchCV(DecisionTreeClassifier(), param_grid=param_grid, cv=5, return_train_score=True)
grid.fit(train_data_data.values, train_data_labels)

results = pd.DataFrame(grid.cv_results_)

# TODO:
# annot=True
# ticks
# Important: The plots should be readable and informative! 
# Training acc / Validation acc

# %%
# mean train score
scores = results.pivot(index='param_max_depth', columns='param_min_samples_leaf', values='mean_train_score')

plt.figure(figsize=(14, 8))
sns.heatmap(scores, annot=True, cmap='YlGnBu_r')
plt.xlabel('Min Samples Leaf')
plt.ylabel('Max Depth')
plt.title('Mean Train Accuracy')
plt.show()

# %%
# mean validation score
scores = results.pivot(index='param_max_depth', columns='param_min_samples_leaf', values='mean_test_score')

plt.figure(figsize=(14, 8))
sns.heatmap(scores, annot=True, cmap='YlGnBu_r', vmin=0.6, vmax=0.8)
plt.xlabel('Min Samples Leaf')
plt.ylabel('Max Depth')
plt.title('Mean Validation Accuracy')
plt.show()

# %%
max_depth = 7
min_samples_per_leaf = 15
id3 = DecisionTreeClassifier(criterion='entropy', max_depth=max_depth, min_samples_leaf=min_samples_per_leaf)
id3.fit(train_data_data.values, train_data_labels)

test_score = id3.score(test_data_data.values, test_data_labels)
print(test_score)
# Out:
# 0.736

# %% [markdown]
# ## Part 3: Linear SVM and Polynomial Kernel

# %%
train_data_frame = pd.read_csv('prepared_train_data.csv')
data_frame_data = train_data_frame[['PCR_01', 'PCR_03']]
data_frame_labels = train_data_frame['spread']
test_data_frame = pd.read_csv('prepared_test_data.csv')
test_data_data = test_data_frame[['PCR_01', 'PCR_03', 'spread']]
test_data_labels = test_data_frame['spread']

# %%
from sklearn.base import BaseEstimator, ClassifierMixin

class SoftSVM(BaseEstimator, ClassifierMixin):
    """
    Custom C-Support Vector Classification.
    """
    def __init__(self, C: float, lr: float = 1e-5, batch_size = 32):
        """
        Initialize an instance of this class.
        ** Do not edit this method **

        :param C: inverse strength of regularization. Must be strictly positive.
        :param lr: the SGD learning rate (step size)
        """
        self.C = C
        self.lr = lr
        self.batch_size = batch_size
        self.w = None
        self.b = 0.0

    # Initialize a random weight vector
    def init_solution(self, n_features: int):
        """
        Randomize an initial solution (weight vector)
        ** Do not edit this method **

        :param n_features:
        """
        self.w = np.random.randn(n_features)
        self.b = 0.0

    @staticmethod
    def loss(w, b: float, C: float, X, y):
        """
        Compute the SVM objective loss.

        :param w: weight vector for linear classification; array of shape (n_features,)
        :param b: bias scalar for linear classification
        :param C: inverse strength of regularization. Must be strictly positive.
        :param X: samples for loss computation; array of shape (n_samples, n_features)
        :param y: targets for loss computation; array of shape (n_samples,)
        :return: the Soft SVM objective loss (float scalar)
        """
        margins = (X.dot(w) + b).reshape(-1, 1)
        hinge_inputs = np.multiply(margins, y.reshape(-1, 1))
        norm = np.linalg.norm(w)
        loss = norm + C * np.sum(np.maximum(0, 1 - hinge_inputs))

        return loss


    @staticmethod
    def subgradient(w, b: float, C: float, X, y):
        """
        Compute the (analytical) SVM objective sub-gradient.

        :param w: weight vector for linear classification; array of shape (n_features,)
        :param b: bias scalar for linear classification
        :param C: inverse strength of regularization. Must be strictly positive.
        :param X: samples for loss computation; array of shape (n_samples, n_features)
        :param y: targets for loss computation; array of shape (n_samples,)
        :return: a tuple with (the gradient of the weights, the gradient of the bias)
        """
        
        threshold = np.vectorize(lambda x:-1 if x < 1 else 0)

        margins = (X.dot(w) + b).reshape(-1, 1)
        unhinged = np.multiply(margins, y.reshape(-1, 1))
        g_w = 2 * w + C * np.sum(np.multiply(np.multiply(threshold(unhinged), y.reshape(-1, 1)), X), axis=0)
        g_b = C * np.sum(np.multiply(threshold(unhinged), y.reshape(-1, 1)))
        
        return g_w, g_b

    def fit_with_logs(self, X, y, max_iter: int = 2000, keep_losses: bool = True):
        """
        Fit the model according to the given training data.

        :param X: training samples; array of shape (n_samples, n_features)
        :param y: training targets (+1 and -1); array of shape (n_samples,)
        :param max_iter: number of SGD iterations
        :param keep_losses:
        :return: the training losses and accuracies during training
        """
        # Initialize learned parameters
        self.init_solution(X.shape[1])

        losses = []
        accuracies = []

        if keep_losses:
            losses.append(self.loss(self.w, self.b, self.C, X, y))
            accuracies.append(self.score(X, y))

        permutation = np.random.permutation(len(y))
        X = X[permutation, :]
        y = y[permutation]
        
        # Iterate over batches
        for iter in range(0, max_iter):
            start_idx = (iter * self.batch_size) % X.shape[0]
            end_idx = min(X.shape[0], start_idx + self.batch_size)
            batch_X = X[start_idx:end_idx, :]
            batch_y = y[start_idx:end_idx]

            g_w, g_b = self.subgradient(self.w, self.b, self.C, batch_X, batch_y)

            # Perform a (sub)gradient step
            self.w -= self.lr * g_w
            self.b -= self.lr * g_b

            if keep_losses:
                losses.append(self.loss(self.w, self.b, self.C, X, y))
                accuracies.append(self.score(X, y))

        return losses, accuracies

    def fit(self, X, y, max_iter: int = 2000):
        """
        Fit the model according to the given training data.
        ** Do not edit this method **

        :param X: training samples; array of shape (n_samples, n_features)
        :param y: training targets (+1 and -1); array of shape (n_samples,)
        :param max_iter: number of SGD iterations
        """
        self.fit_with_logs(X, y, max_iter=max_iter, keep_losses=False)

        return self

    def predict(self, X):
        """
        Perform classification on samples in X.

        :param X: samples for prediction; array of shape (n_samples, n_features)
        :return: Predicted class labels for samples in X; array of shape (n_samples,)
                 NOTE: the labels must be either +1 or -1
        """
        # TODO: compute the predicted labels (+1 or -1)
        y_pred = np.sign(X.dot(self.w) + self.b)
        y_pred[y_pred == 0] = 1  # if the result is ON THE MARGIN, we consider it as positive

        return y_pred

# %%
def numerical_subgradient(w, b, C, X, y, delta=1e-4):
    w_ = w.copy()
    g_w = np.zeros_like(w_)
    orig_objective = SoftSVM.loss(w_, b, C, X, y)
    for i in range(g_w.shape[0]):
        w_[i] += delta
        perturbed_objective = SoftSVM.loss(w_, b, C, X, y)
        w_[i] -= delta
        g_w[i] = (perturbed_objective - orig_objective) / delta

    g_b = (SoftSVM.loss(w_, b + delta, C, X, y) - orig_objective) / delta
    return g_w, g_b



def compare_gradients(X, y, deltas, C=1, REPEATS=100, figsize=(10, 6)):
    residual_means = []

    for delta in deltas:
        residuals = []

        for _ in range(REPEATS):
            # Randomize vectors in which the gradient is computed
            w = np.random.randn(X.shape[1])
            b = np.random.randn(1)

            # Compute the two types of gradients
            analytic_grad = SoftSVM.subgradient(w, b, C, X, y)[0]
            numeric_grad = numerical_subgradient(w, b, C, X, y, delta=delta)[0]

            residual = np.linalg.norm(numeric_grad - analytic_grad)
            residuals.append(residual)

        residual_means.append(np.mean(residuals))

    plt.figure(figsize=figsize)
    plt.title('Residuals of analytical and numerical gradients', fontsize=22)
    plt.plot(deltas, residual_means, linewidth=3)      
    plt.yscale('log')
    plt.xscale('log')
    plt.xlabel(r'$\delta$', fontsize=18)
    plt.ylabel(r'$\left\Vert \nabla_{w}p_{C}\left(w,b\right) - u_{\delta} \left(w,b\right)\right\Vert$', fontsize=18)

    # plt.grid(alpha=0.5)
    plt.grid(which='both', linestyle='-', linewidth='0.5', color='gray')

    # Customize the major grid
    plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
    plt.show()

# %% [markdown]
# ## Q9

# %%
# compare_gradients()
# plt.grid(True)
compare_gradients(data_frame_data.values, data_frame_labels.values, deltas=np.logspace(-5, -1, 10))

# %% [markdown]
# ## Q11

# %%
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
X_train = data_frame_data.values
y_train = data_frame_labels.values
X_train_poly = PolynomialFeatures(degree=3, include_bias=False).fit_transform(X_train) 
X_train_poly = MinMaxScaler(feature_range=(-1,1)).fit_transform(X_train_poly)

# %%
C=1e5 

for lr in np.logspace(-9, -5, 5):
    clf = SoftSVM(C=C, lr=lr) 
    losses, accuracies = clf.fit_with_logs(X_train_poly, y_train, max_iter=15000)
    # losses, accuracies = clf.fit_with_logs(X_train, y_train, max_iter=5000) 
    plt.figure(figsize=(13, 6)) 
    plt.subplot(121), plt.grid(alpha=0.5), plt.title ("Training Loss") 
    plt.semilogy(losses), plt.xlabel("Step"), plt.ylabel("Loss") 
    plt.subplot(122), plt.grid(alpha=0.5), plt.title ("Training Accuracy") 
    plt.plot(accuracies), plt.xlabel("Step"), plt.ylabel("Accuracy") 
    plt.suptitle(f"Learning rate: {lr}")
    plt.tight_layout() 
    plt.show()

# %%
test_data_frame = pd.read_csv('prepared_test_data.csv')
X_test = test_data_frame[['PCR_01', 'PCR_03']].values
y_test = test_data_frame['spread']
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
p_features = PolynomialFeatures(degree=3, include_bias=False)
svm_clf = Pipeline([('feature_mapping', p_features),  ('scaler', MinMaxScaler()), ('SVM', SoftSVM(C=1e5, lr=1e-7))]) 
svm_clf.fit(X_train, y_train, SVM__max_iter=5000) 

# graph the trained model's decision boundary
visualize_clf(svm_clf, X_train, y_train, 'Soft SVM with Polynomial Features', xlabel='PCR_01', ylabel='PCR_03')
print(f"Train score: {svm_clf.score(X_train, y_train)}")
print(f"Test score: {svm_clf.score(X_test, y_test)}")
# Out:
# Train score: 0.811
# Test score: 0.82

# %%
from sklearn.svm import SVC
train_data_frame = pd.read_csv('prepared_train_data.csv')
test_data_frame = pd.read_csv('prepared_test_data.csv')
pcr_1_3_train_data = train_data_frame[['PCR_01', 'PCR_03']].values
pcr_1_3_test_data = test_data_frame[['PCR_01', 'PCR_03']].values
train_data_labels = train_data_frame['spread']
test_data_labels = test_data_frame['spread']

svc = SVC(C=1, gamma=1e-7, kernel='rbf')
svc.fit(pcr_1_3_train_data, train_data_labels)
visualize_clf(svc, pcr_1_3_train_data, train_data_labels, 'SVM with RBF kernel\ngamma = 1e-7', xlabel='PCR_01', ylabel='PCR_03')

svc = SVC(C=1, gamma=5000, kernel='rbf')
svc.fit(pcr_1_3_train_data, train_data_labels)
visualize_clf(svc, pcr_1_3_train_data, train_data_labels, 'SVM with RBF kernel\ngamma = 5000', xlabel='PCR_01', ylabel='PCR_03')

# svc = SVC(C=1, gamma=0.0001, kernel='rbf')
# svc.fit(pcr_1_3_train_data, train_data_labels)
# visualize_clf(svc, pcr_1_3_train_data, train_data_labels, 'SVM with RBF kernel\ngamma = 5000', xlabel='PCR_01', ylabel='PCR_03')

# %%
from sklearn.svm import SVC
train_data_frame = pd.read_csv('prepared_train_data.csv')
train_data_frame = train_data_frame[train_data_frame["is_special_blood"] == -1]
pcr_2_6_full_data = train_data_frame[['PCR_02', 'PCR_06', 'risk']]

pcr_2_6_train_data = train_data_frame[['PCR_02', 'PCR_06']].values

test_data_frame = pd.read_csv('prepared_test_data.csv')
test_data_frame = test_data_frame[test_data_frame["is_special_blood"] == -1]
pcr_2_6_full_test_data = test_data_frame[['PCR_02', 'PCR_06', 'risk']]

pcr_2_6_test_data = test_data_frame[['PCR_02', 'PCR_06']].values
pcr_2_6_train_data_labels = train_data_frame['risk']
pcr_2_6_test_data_labels = test_data_frame['risk']

# %%
plt.figure(figsize=(10, 10))
sns.jointplot(data=pcr_2_6_full_data, x='PCR_02', y='PCR_06', hue='risk', palette={-1: 'red', 1: 'green'}, s=100, alpha=0.5)
plt.xlim(-1.2, 1.5)
plt.ylim(-1.2, 1.5)
plt.legend(loc='upper right', title='risk')
plt.suptitle('PCR_02 vs. PCR_06\nnot special blood')
plt.grid(True)
plt.show()

# %% [markdown]
# # task

# %%
pcr_2_6_full_data.loc[:, 'angle'] = pcr_2_6_full_data.apply(lambda row: np.arctan2(row['PCR_06'], row['PCR_02']), axis=1)
# Out:
# /tmp/ipykernel_243485/2114478892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pcr_2_6_full_data.loc[:, 'angle'] = pcr_2_6_full_data.apply(lambda row: np.arctan2(row['PCR_06'], row['PCR_02']), axis=1)

# %%
plt.figure(figsize=(15, 5)) 
sns.scatterplot(data=pcr_2_6_full_data, x='angle', y=[0]*pcr_2_6_full_data.shape[0], hue='risk', s=130) 
sns.kdeplot(data= pcr_2_6_full_data, x='angle', hue='risk', common_norm=True, fill=False) 
plt.grid(True)
plt.title("Density of points in the angle space")
plt.ylim(bottom=-1e-2)
# Out:
# (-0.01, 0.11681550719029579)

# %%
beta=4
pcr_2_6_full_data.loc[:, 'sin_angle'] = np.sin(beta*pcr_2_6_full_data['angle'])
# plot an sns jointplot of the angle and sin_angle
plt.figure(figsize=(10, 10))
sns.jointplot(data=pcr_2_6_full_data, x='angle', y='sin_angle', hue='risk', palette={-1: 'red', 1: 'green'}, s=100, alpha=0.5)
plt.grid(True)
plt.suptitle('Mapping of points to (angle, sin_angle) space')
# Out:
# /tmp/ipykernel_243485/2455311710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pcr_2_6_full_data.loc[:, 'sin_angle'] = np.sin(beta*pcr_2_6_full_data['angle'])
# Text(0.5, 0.98, 'Mapping of points to (angle, sin_angle) space')

# %%
beta_sums = {}
angles = {}
labels = pcr_2_6_full_data['risk']
for beta in np.arange(1, 5.1, 0.001):
    angles[beta] = np.sin(beta*pcr_2_6_full_data['angle'])
    positive_indexes = angles[beta] > 0
    positive_index_label_sum = labels[positive_indexes].sum()
    beta_sums[beta] = abs(positive_index_label_sum)
    # pcr_2_6_full_data.loc[:, f'sin_angle_{beta}'] = np.sin(beta*pcr_2_6_full_data['angle'])
    # label_sum = pcr_2_6_full_data[pcr_2_6_full_data[f'sin_angle_{beta}'] > 0]['risk'].sum()
    # label_sum = pcr_2_6_full_data[angles[beta] > 0]['risk'].sum()
    # beta_sums[beta] = abs(label_sum)
# get beta, sum for the biggest sum
max_beta = max(beta_sums, key=beta_sums.get)
print(f"Max beta: {max_beta}, sum: {beta_sums[max_beta]}")
# Out:
# Max beta: 4.123999999999656, sum: 192

# %%
pcr_2_6_full_data.loc[:, 'sin_angle_4.124'] = np.sin(np.pi*4.124*pcr_2_6_full_data['angle'])
pcr_2_6_full_data['sin_angle_4.124'] = MinMaxScaler(feature_range=(-1, +1)).fit_transform(pcr_2_6_full_data[['sin_angle_4.124']])
angle_sin_angle_4124 = pcr_2_6_full_data[['angle', 'sin_angle_4.124']].values
svc_4124 = SVC(C=1, gamma=1, kernel='linear')
svc_4124.fit(angle_sin_angle_4124, pcr_2_6_train_data_labels)
visualize_clf(svc_4124, angle_sin_angle_4124, pcr_2_6_train_data_labels, 'Linear SVM with beta = 4.124', xlabel='angle', ylabel='sin_angle_4.124')
train_score = svc_4124.score(angle_sin_angle_4124, pcr_2_6_train_data_labels)
print(f"train score for beta=4.124: {train_score}")
# Out:
# train score for beta=4.124: 0.8674463937621832

# %%
beta_1 = 4 * np.pi
pcr_2_6_full_data.loc[:, 'sin_angle_4'] = np.sin(beta_1*pcr_2_6_full_data['angle'])
# scale the angle to (-1, +1)
pcr_2_6_full_data['sin_angle_4'] = MinMaxScaler(feature_range=(-1, +1)).fit_transform(pcr_2_6_full_data[['sin_angle_4']])
pcr_2_6_full_data['angle'] = MinMaxScaler(feature_range=(-1, +1)).fit_transform(pcr_2_6_full_data[['angle']])

angle_sin_angle_4 = pcr_2_6_full_data[['angle', 'sin_angle_4']].values

pcr_2_6_full_data = pcr_2_6_full_data.copy()

svc_4 = SVC(C=1, gamma=1, kernel='linear')
svc_4.fit(angle_sin_angle_4, pcr_2_6_train_data_labels)
visualize_clf(svc_4, angle_sin_angle_4, pcr_2_6_train_data_labels, 'Linear SVM with beta = 4', xlabel='angle', ylabel='sin_angle_4')
train_score = svc_4.score(angle_sin_angle_4, pcr_2_6_train_data_labels)
print(f"train score for beta=4: {train_score}")
# Out:
# train score for beta=4: 0.8499025341130604

# %%
# transform the test data to use angle, sin_angle_4.124
pcr_2_6_full_test_data.loc[:, 'angle'] = pcr_2_6_full_test_data.apply(lambda row: np.arctan2(row['PCR_06'], row['PCR_02']), axis=1)
pcr_2_6_full_test_data.loc[:, 'angle'] = MinMaxScaler(feature_range=(-1, +1)).fit_transform(pcr_2_6_full_test_data[['angle']])
pcr_2_6_full_test_data.loc[:, 'sin_angle_4'] = np.sin(4.124*np.pi*pcr_2_6_full_test_data['angle'])
pcr_2_6_full_test_data.loc[:, 'sin_angle_4'] = MinMaxScaler(feature_range=(-1, +1)).fit_transform(pcr_2_6_full_test_data[['sin_angle_4']])
pcr_2_6_full_test_data = pcr_2_6_full_test_data.copy()

test_angle_sin_angle_4 = pcr_2_6_full_test_data[['angle', 'sin_angle_4']].values
test_score = svc_4124.score(test_angle_sin_angle_4, pcr_2_6_test_data_labels)
print(f"test score for beta=4: {test_score}")
# Out:
# test score for beta=4: 0.8633093525179856
